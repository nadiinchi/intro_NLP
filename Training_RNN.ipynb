# %% [markdown]
# # Обучение рекуррентной нейронной сети для генерации текстов
#
# В этом ноутбуке мы обучим рекуррентную нейросеть небольшого размера на первом томе романа "Война и мир" Л. Н. Толстого. Такая нейронная сеть будет уметь генерировать продолжения фраз на русском языке. В задании Вы попробуете выполнять такие предсказания.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
from collections import Counter
import os
from argparse import Namespace

# %% [markdown]
# ### Гиперпараметры

# %%
flags = Namespace(
    train_file='VoinaIMir.txt', # файл с данными
    seq_size=32, # максимальная длина текста (в словах)
    batch_size=16, # размер мини-батча
    embedding_size=64, # число элементов в векторных представлениях слов
    lstm_size=64, # число нейронов в рекуррентном слое
    gradients_norm=5 # ограничение на норму градиентов (улучшает обучение)
)

# %% [markdown]
# ### Загрузка данных
#
# Функция get_data_from_file выполняет следующие действия:
# * чтение файла с данными
# * сборка словаря (всех возможных слов) и сортировка по частоте
# * предобработка данных (замена слов на числа - индексы в словаре)
#
# Функция get_batches генерирует мини-батчи для обучения.

# %%
def get_data_from_file(train_file, batch_size, seq_size):
    # чтение файла с данными
    with open(train_file, 'r', encoding='utf-8') as f:
        text = f.read()
    text = text.split()

    # сборка словаря (всех возможных слов) и сортировка по частоте
    word_counts = Counter(text)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {k: w for k, w in enumerate(sorted_vocab)}
    vocab_to_int = {w: k for k, w in int_to_vocab.items()}
    n_vocab = len(int_to_vocab)

    print('Размер словаря', n_vocab)

    # предобработка данных
    int_text = [vocab_to_int[w] for w in text]
    num_batches = int(len(int_text) / (seq_size * batch_size))
    in_text = int_text[:num_batches * batch_size * seq_size]
    out_text = np.zeros_like(in_text)
    out_text[:-1] = in_text[1:]
    out_text[-1] = in_text[0]
    in_text = np.reshape(in_text, (batch_size, -1))
    out_text = np.reshape(out_text, (batch_size, -1))
    return int_to_vocab, vocab_to_int, n_vocab, in_text, out_text


def get_batches(in_text, out_text, batch_size, seq_size):
    num_batches = np.prod(in_text.shape) // (seq_size * batch_size)
    for i in range(0, num_batches * seq_size, seq_size):
        yield in_text[:, i:i+seq_size], out_text[:, i:i+seq_size]

# %% [markdown]
# Загрузим данные:

# %%
int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = \
    get_data_from_file(
    flags.train_file,\
    flags.batch_size, \
    flags.seq_size)
# Out:
# Размер словаря 22782

# %%
n_vocab
# Out:
# 22782

# %% [markdown]
# Посмотрим на 20 самых частых слов:

# %%
for idx in range(20):
    print(int_to_vocab[idx])
# Out:
# ,
# .
# и
# —
# в
# не
# на
# что
# он
# с
# как
# !
# к
# его
# ?
# сказал
# я
# было
# это
# ;

# %% [markdown]
# Найдем номер слова "Наташа":

# %%
vocab_to_int["Наташа"]
# Out:
# 252

# %% [markdown]
# А вот как выглядит одна строчка обработанных данных (это номера слов в словаре):

# %%
in_text[0, :10]
# Out:
# array([8635, 5267, 8636, 8637, 8638, 3804,   34, 8639,    2,  965])

# %% [markdown]
# ### Сборка нейросети

# %%
class RNNModule(nn.Module):
    def __init__(self, n_vocab, seq_size, embedding_size, lstm_size):
        super(RNNModule, self).__init__()
        self.seq_size = seq_size
        self.lstm_size = lstm_size
        # слой векторных представлений (эмбеддингов)
        self.embedding = nn.Embedding(n_vocab, embedding_size)
        # рекуррентный слой
        self.lstm = nn.LSTM(embedding_size,
                            lstm_size,
                            batch_first=True)
        # полносвязный слой для предсказания следующего слова
        self.dense = nn.Linear(lstm_size, n_vocab)

    def forward(self, x, prev_state):
        # x: (16, 32): 16 объектов, 32 слова в каждом
        embed = self.embedding(x) # (16, 32, 64): 64 - размер векторного представления
        output, state = self.lstm(embed, prev_state) # (16, 32, 64)
        logits = self.dense(output) # (16, 32, 22782), 22782 - число слов в словаре

        return logits, state

    def zero_state(self, batch_size):
        return (torch.zeros(1, batch_size, self.lstm_size),
                torch.zeros(1, batch_size, self.lstm_size))

# %% [markdown]
# Функция для задания оптимизируемого критерия и оптимизитора:

# %%
def get_loss_and_train_op(net, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    return criterion, optimizer

# %% [markdown]
# Функция для выполнения предсказания (закончить данный текст):

# %%
def predict(device, net, n_vocab, vocab_to_int, int_to_vocab,
             words="Зачем мне", top_k=5, length=100):
    words = words.split()
    
    net.eval()

    # обработка данных слов
    state_h, state_c = net.zero_state(1)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    for w in words:
        ix = torch.tensor([[vocab_to_int[w]]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))

    # предсказание первого следующего слова (случайный выбор из top_k слов)
    _, top_ix = torch.topk(output[0], k=top_k)
    choices = top_ix.tolist()
    choice = np.random.choice(choices[0])

    words.append(int_to_vocab[choice])

    # повторение процедуры генерации length раз
    for _ in range(length):
        ix = torch.tensor([[choice]]).to(device)
        output, (state_h, state_c) = net(ix, (state_h, state_c))

        _, top_ix = torch.topk(output[0], k=top_k)
        choices = top_ix.tolist()
        choice = np.random.choice(choices[0])
        words.append(int_to_vocab[choice])

    print(' '.join(words))
    return ' '.join(words)

# %% [markdown]
# ### Обучение нейросети

# %%
# устройство, на котором будут храниться модель и мини-батчи
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# создаем конкретный экземпляр нейросети
net = RNNModule(n_vocab, flags.seq_size,
                flags.embedding_size, flags.lstm_size)
# переносим нейросеть на устройство
net = net.to(device)

# оптимизируемый критерий, оптимизатор
criterion, optimizer = get_loss_and_train_op(net, 0.01)

iteration = 0

# цикл по эпохам
for e in range(200):
    batches = get_batches(in_text, out_text, flags.batch_size, flags.seq_size)
    state_h, state_c = net.zero_state(flags.batch_size)
    state_h = state_h.to(device)
    state_c = state_c.to(device)
    # цикл по мини-батчам
    for x, y in batches:
        iteration += 1
        net.train()

        optimizer.zero_grad()
        
        # переносим мини-батч на устройство
        x = torch.tensor(x).to(device)
        y = torch.tensor(y).to(device)

        # проход вперед - вычиссление предсказаний
        logits, (state_h, state_c) = net(x, (state_h, state_c))
        
        # вычисление критерия
        loss = criterion(logits.transpose(1, 2), y)

        loss_value = loss.item()

        # проход назад - вычисление производных
        loss.backward()

        state_h = state_h.detach()
        state_c = state_c.detach()

        _ = torch.nn.utils.clip_grad_norm_(
            net.parameters(), flags.gradients_norm)

        # обновление параметров модели
        optimizer.step()

        # иногда печатаем промежуточные результаты
        if iteration % 1000 == 0:
            print('Epoch: {}/{}'.format(e, 200),
                  'Iteration: {}'.format(iteration),
                  'Loss: {}'.format(loss_value))
            predict(device, net, n_vocab,
                    vocab_to_int, int_to_vocab, top_k=5)
# Out:
# Vocabulary size 22782
# Epoch: 3/200 Iteration: 1000 Loss: 4.871341228485107
# Зачем мне самую плохую , я вам скажу ! … Я рад , как и — кричал четвертый , что он , как и не только в тумане , — сказала она , но с большим роты , что в то , — сказал Кутузов . « Но он сам , и он видел его высочество , но , что это не мог быть иначе и , но в самом изящном или к себе . — Я знаю . — Да ! » думал князь Василий в тумане . В одной день то на него , — продолжал он , и не было
# Epoch: 7/200 Iteration: 2000 Loss: 3.65338397026062
# Зачем мне удовлетворение… ] что ? А ? ! — обратился Анатоль в то же место занимают и изящества . В то мгновение куда что она затевала между Шлапаницем в отчаянии и не может не понравиться накануне , и в лесу , и более и крик . « Ежели вы отправляете , я вас . — Что греха таить не будет . — Вы знаете за границей . [ Этот послал к petite est un… ] желает назначения Жюли ; но не позволю нему ! что не может видеть и не так на себе нынче ? … Я думаю . И она не
# Epoch: 10/200 Iteration: 3000 Loss: 2.91375732421875
# Зачем мне строгий прически выражения глаз с французскими пор — , чтобы поровняться ее , и 'азделяю ногой . Я тебе не только в том положении , то поверь руки . ] И как в Нем есть княжен , — продолжал Билибин . — Ну не , я ничего не знаю . « Ну , моя голубушка , — продолжал Билибин , mon père Багратиона , чтобы это не годны… находились . Государи генерал , — сказал Борис , а теперь я думаю ! что вы думаете ? ] Мальчишкам , как я думаю . Я только не помню . Мы одни кожу
# Epoch: 14/200 Iteration: 4000 Loss: 2.7858774662017822
# Зачем мне Знаете и огонь к Ипполиту , — говорил он офицерам : [ Почему же последний походом к старому себе . Он подошел послушать . Он не мог не так же , и на лафет самая . Как в тумане старался простым à la surprendre un pareil войска сражений à la main d'une du pont » . Je crains и подвертки улыбаясь или несогласен было Бонапарта , и неожиданно перервал офицеров ( каждое приказание до княжны , как на средине графини оставались . В приемной и о молодом . Он знал , — продолжал полковой командир ; я попрошу Андрея и защищает
# Epoch: 18/200 Iteration: 5000 Loss: 2.566495418548584
# Зачем мне забыты . — Да вы постойте и посмотрим дорогу , впереди и спотыкающегося разговора из-под voilà ударяя приняло перед писарем и тихо стал . Налево внизу стрельба от нее . « Где я знаю ? Я не желаю говорить это было у него наедине . Я не знаю , как актер он , чем на место — подумал князь Андрей ? Я вижу еще более всего именья и , — повторил Пьер , и посмотрим . В 6-м Вейротера князь Багратион . Он оглянулся сверху вниз , что они обещали ! Никого , как она была обратился с конца , но
# Epoch: 21/200 Iteration: 6000 Loss: 2.590285301208496
# Зачем мне нужно было , и он понапрасну треском к лесу . Казак у министр , раздраженности , готовясь их и покрыты и пленного Жеркова в другую минуту . Солдаты французы в лощине речки слышалась личного строившихся и рассеянно подставлял говорить ей уйти о погоде и этот-то солдат и ружьями . Аудитор он найдет бы по своей комнате . — Что такое равновесие мне , как вы мне , и что , я думаю и помню . Я только в то , как осаждают он и насмешливо на всех . — Граф князь ? ( Le Marierois ! Вечор нельзя объяснить в дверь
# Epoch: 25/200 Iteration: 7000 Loss: 2.117473840713501
# Зачем мне кончил хозяйки разглядеть и простившись с отцом на походе у другого : « princesse , les noms Bourienne , [ смеялись , не приказывая сидели , поднялись , не знал : Сергей В комнате одну неопределенную в полной одном направлении князем улыбающимся и зашевелилось ему : важно скрыть всех решиться и поскакал прочь , когда армия должна от своего великодушия . Перед мороженым смотрели , [ плакса ! Слава отцом , — говорила княгиня . Лицо капитана выражало своим вытянул слушал в порядке в него и Элен : это знает , потому как мо-о-ожно Николай , которого ему теперь то человек
# Epoch: 29/200 Iteration: 8000 Loss: 1.8529788255691528
# Зачем мне . И что она хотела сказать ? ] с роты доходец вы меня нельзя ! Я не могу , как видишь , — продолжал он одушевляясь тоже , что ты мне ничего будет , как у меня скучают есть большая и полковник и указывая на отплывающую государю и гордости воспоминаний меня , и ежели бы он Антихрист ) ; я вам говорю , — повторил Ростов и себя за этого дня ? … И она имела не пыли ли . Он не только для себя в свете в эту небольшую тумана о степени кабинета , но когда она увидела , как
# Epoch: 32/200 Iteration: 9000 Loss: 1.9435428380966187
# Зачем мне лакей подсаживал в руке голос . Анна была написана и о победе и называла руки . Впереди взял из передней , и он знал в гостиную вместе . В то чувством показались дымки руку , который представлял всхлипыванья женщину была спокойно . — Постой , разойми взглянула . Ну ! что у тебя запачкано я увидал ! что я вас и , а вы раздался вам одного фурмана Ростов пристально письмо и попросился , что не так ни этого дальше , не был в том пространство еще четыре лошадей лица лежали , что она не прервет были , — сказала графиня
# Epoch: 36/200 Iteration: 10000 Loss: 1.9646997451782227
# Зачем мне нужно было иметь такого . — И она пожала руку , — je ferai Это смотр . Она смутилась ! — закричал он тоже в деревню заворачивает ) ) , и в воображении своем рассказывая или друга испуганно к ней . Самый лучше вышла из этом . — Он заплакал ! » Ни за ней . И слава Богу ко всякому ) — и я не хочет войны бы вам . Мы вы так похудели за ] и то , и вот как он протянул лошадь и больше в руки . — А я вам то ? что я того ,
# Epoch: 39/200 Iteration: 11000 Loss: 1.6306381225585938
# Зачем мне был бы в волю , и Ростов взял не могу высказать . Я думаю ! — и вьюки , — я знаю , и вы , чтобы не могла выговорить с толку , для чего он мне ничего нет . Я так говорю только , как ты бывает его . А успевают только те платье о m-lle государя своим когда Болконскому , и потому с детства не товарищам . Лошади вдруг спросила гостья . Князь Андрей , судя графиня и такие , что напоминало что-нибудь улыбавшуюся m-lle Бурьен , как сплетничать . Князь Багратион , что ты не откажешь . Я
# Epoch: 43/200 Iteration: 12000 Loss: 1.9123456478118896
# Зачем мне начать . Он держал не только для всех такого Да , но моя бедная мать… ] ) , что она , сплошной немец , великое дело ! ужасно , вы не знаете » ; а к ней и кончавшуюся на своем понять или нераспорядительности , а силу на Анну Михайловну и , где опасно : После темной звездной у князя Голицына в синих вина . Слегка рассматривал рукой и скорее под стол в Браунау и желание возможным за живое думал , и , — я не пущу меня . — Дай мне честное господа . В это важное в случае предполагая
# Epoch: 47/200 Iteration: 13000 Loss: 1.6767233610153198
# Зачем мне никому сказала просит un любви для чего вести каждое интересов , для чего резко им замечанием ! — нахмурившись ты вам была значительно надо . Он боялся иначе не слушал солдата , как он переносит взглядом движением , с которым каждый день . Графиня перед свежим peut-être лучи доброго с предмета с прибавил жалко , бросаясь и с спокойною шел приехал к батарее Тушина , которое она затевала всадников ) и т. д. , le дело . Je vous avoue руки ; я вам предрекаю в поступках батарее князь Андрей с другими девицами побежал голоса угощала нас в угол . Но
# Epoch: 50/200 Iteration: 14000 Loss: 1.779767394065857
# Зачем мне правил это сердце » . ( Он подвел глядя через стол . « Где государь , а как ты , а я не дура ] Анна Бориса к князю Андрею . Но я будет , что вы мне скажете его рад , чтобы помогать нынче вас герой , кроме его , князь Андрей , — не могу рассудить же отца и это за нею дверь , и забыто , как называли первый вошел адъютант и , но всё это могло . Как только не был французской самого . Государь , заведывавший которым ему несколько нужно , стали тем стояли в лорнет
# Epoch: 54/200 Iteration: 15000 Loss: 1.7200847864151
# Зачем мне раздражение : — сказал Пьер , обращаясь — как она к генералу ? Ведь ты не могу упрекнуть в полку не обо мне всё . Но , я делали кого-то . mon mari m'abandonne с сыном с давая чувствовать . Жюли гостьи , зависящая от него . Один говорила графиня был в темнозеленом одну осталось ? В большой линию и ко мне теперь . Но , будут Ростов . Ты слушай всё . Княгиня Лизавета безнадежно . — А я держусь тех рукой . ] Княгиня что не знают это ни было , но я покажу ему и лучше нашего свободы
# Epoch: 58/200 Iteration: 16000 Loss: 1.7049589157104492
# Зачем мне делать сцены в очки в конце дела в кибиточке и преданность ( одна шли два письма еще , чтобы офицер испытывал то робкое на фланг своего оплакиваемого на будущем и , что поехали что французы легко и деньги его ; бросает перед революции была гостиной перед государем военного государя и князем государя на место на воли , всегда русский офицер и становилось без императору . — Вы не замечал » . Да что ж это упало и больше прижимал этого общества государю , но я не понимаю это , так боялись про себя ; но в стороне вести каждое , что
# Epoch: 61/200 Iteration: 17000 Loss: 1.8984248638153076
# Зачем мне начать . Она достала в комнату не мешают ему женой доброго и даже и не только больше распространялись видал исполнить той детства глаз , — говорил другой . Довольны он с вами в разных их жизни теперь ! Ну или возбуждать его вас свою своего воспитанника и ей женою . Он не только в то же , — не желал бутылку ! Ты теперь никакого труда , с Борисом ! уж чувствует деньги . Пьер не говорил ему теперь и думать по нем пор в детства еще , которые это точно желая обойти сын во всю удовольствия на предмет дела .
# Epoch: 65/200 Iteration: 18000 Loss: 1.6472928524017334
# Зачем мне отвечали ему так , и , и что б одно в двух местах , он по той при маленькой , послышался через несколько шагов ; потом не только князем , но тем же взгляд от его души еще предлог , чтобы не могла понять , недостаток его в холмы , а мы все разошлись ; он развязал смеялись и звуки с своими однообразно-разнообразными лицами и беспрестанно на друга на него глазами только полком , Ростов что-то видит в комнату вошел к князю Василью , — с выражением нервного ту же , как он сам не неправду Да : что она не
# Epoch: 69/200 Iteration: 19000 Loss: 1.4420057535171509
# Зачем мне несчастие у вас ; но она , не отвечая и уехали , и даже указывая прямо в сердце , где она вышла у брата , а я вам тоже и не сказал , что же я вам говорил . Я вас люблю его в то на волю дела » , подумал Борис . Борис еще далеко чего-нибудь Ростов из князя и решение ее крепко и по-французски сказал ему в его . « И я думала , вы говорите , ] Анна денег без графиню ; но она очень огорчен . Когда смотр французы величественной радости . Они вошли , позади какой-то
# Epoch: 72/200 Iteration: 20000 Loss: 1.5605829954147339
# Зачем мне привести в эту минуту не было вам думает , третье стоят бы и я буду первою остановка солдат относились в знак того большого человека в штатском платье еще что было слишком много обстоятельств и о победе и всякий человек у него . Ростов не приходила , видневшиеся направо : глаза и не человек с ее книгу . — Я то самое , ] кто станешь к батюшке всего . А это ужасно ; я думаю ему и теперь с беременною женой . Я так буду счастлива , а Тит , право . ] ( Несмотря прямо то ни в знак того
# Epoch: 76/200 Iteration: 21000 Loss: 1.5451947450637817
# Зачем мне военного казалось ; муж того добра и с улыбкой на концах волю , а то к чему к старому . Она богата , не могу , не могу подавить некоторую скрытую , он , до такой человека , и в свои года его и оживленного обращался , он был влюблен на графа , что это было всё еще более выказывая свои мысли в неприятельский положение человека эту минуту , чтобы черед спросить не приходила ей ? Наверно отворилась ? » подумал Ростов , и ударив , — обратился князь . Впрочем Бориса , завтра бы не было у меня всё .
# Epoch: 79/200 Iteration: 22000 Loss: 1.2905055284500122
# Зачем мне жить , — сказала мать , заметив Бориса и не любили ; а как она войдет и не находит тех он и в ту же минуту показались студент , но только кроме того времени ) : сражение за русской армии и презрительно Тихона . Ростов видел . Пьер хотел сначала объяснить , ] но из сострадания не перевязанных . Князю Василью ужас и за письмо в комнату к бюро , он громко к Пьеру ; старый князь , сопутствуемый видом молодцов-апшеронцев и на всех этих гусар ; фигура много Вейротера и некрасиво . — Всё — сказала ее ординарцем очень интересует
# Epoch: 83/200 Iteration: 23000 Loss: 1.5150305032730103
# Зачем мне ( что не может сделать , радостнее стояли видел еще не князю , увидав , — и я навсегда ее , вы его с отцом и вообще как я люблю это его убьет ! » И Наташа побежала в Вене всё , что все более все более на несколько недель в гостиной ; до которых не находил ему дорогу : он отдал они сами на лице и вопросительно в том оживленное маленькой серой арабской полную Марьи Викторовны их с несколько виноватым чувствовал тут . Он заметил много , и он обратился и в девках , установился теперь свой фантастический мир !
# Epoch: 87/200 Iteration: 24000 Loss: 1.4115372896194458
# Зачем мне странные ) и наивно в нем ; и никак не в духе ; люди не убитых , серенькое он проехать леса и на ее прекрасных , и лицо ее жизни , не разошелся и все были дым и добрым с удовольствием не счастливым его к князю и взгляд своих слушателей : — C'est un pauvre coeur ne me sont de faire mon père ; je них . — C'est bien , et Sa qui brave bien получил . Вы командир приходится подле двух супов бы , что за обеды ! ] — une institution ' , с веками . Здесь у
# Epoch: 90/200 Iteration: 25000 Loss: 1.553160548210144
# Зачем мне обходят всех идет , выказывая до приезда только замечал его . Он говорил ему : Но Ростов ничего желал , дверь отворилась , что ему делать быть родоначальником рода . — Ну вот тебе письмо . Князь Ауэрсперг раненый Марья Козловский оглянулся и вздохнул . ] — Ax же , я вам говорю ! — повторялось и Богданычем , потерял , на немцев к себе , которую поцеловал Алпатыч , что русская были на него смотрят к лицу князю . Княжна ошиблась хотела вспоминая , чтобы всё более войска , в рядах государя составляющее в тумане костров шпагу , имеющими звуки
# Epoch: 94/200 Iteration: 26000 Loss: 1.5017800331115723
# Зачем мне думает . Он кликнул ее слушал себя в лице камердинера князя и весело смотрел . Он заметил за то , — сказала мать умоляющим голосом мост . Одни и над дальний , быстро головой и сел за соседний стол в эту ростом , в его пушки и , и хорошо оглядывался решил : делать уже был чужой , молча глядела на минуту и свою любовь под шинели на французский кучер этой мысли и Элен наших и гвардейский тех же первых старшая Элен и стал несколько позади государя на его лицах . Князь всё помнил свою диспозицию лошадь , появившегося из-под армии
# Epoch: 98/200 Iteration: 27000 Loss: 1.5976742506027222
# Зачем мне бродя гусарский визитов и стоявших которые , но , как Борис , прищурившись : маленькая ее не только пойду и им над толпой о недавнем щеголеватых героем в неприятельской комнаты . — Это ваша Тушин не говоря человека в этом не будет в него , и есть , приехал про политику ? Я его сделали пропозицию за другим , как мы выросли и в пехоте , на которое его месте . Он заметил , как в Петербурге , в котором был был который вспоминал еще менее им на него . Она сказала… — Болконского пальцем перед ротой ; князь Василий говорил
# Epoch: 101/200 Iteration: 28000 Loss: 1.9260355234146118
# Зачем мне бывала полковому не дают Николая , вы позаботились в плен голову , ] а коли вы нам армия уничтожена ( она не знаю , что это будет , то можете только в том , моя поговорим . Эй с князем Долгоруковым лицом за детства договорить солдата . — Вот я не могу оставаться ! Государь и не находишь это для себя хорошо знаю и теперь ? — сказал он , глядя на выходе шпагу в столовую и , обращаясь на нее . — Ну , вы назад благодарить перед обедом опять приняло то на его месте . Он в темнозеленом ,
# Epoch: 105/200 Iteration: 29000 Loss: 1.341120958328247
# Зачем мне думает и по-французски из комнаты больного , и вдруг продвинулся на один на лице четыре еще . Увидав четыре , которые , всё обман только моим слова , — сказал Борис ; ну » Кутузов что государь уже был за тем же аллюром ему хотелось голосов так долго простояли в эту ночь в движении , подозвал нее и графиня этой ловить после . Анна Михайловна самым незаметным , стараясь в Петербурге и имеет у себя . Марья был одна из другом . молодом был делает , а виноват княжна Болконского и в той , отдал он облокотился на этой пехоты в
# Epoch: 109/200 Iteration: 30000 Loss: 1.3795771598815918
# Зачем мне судьба занимал приходили дама . Кутузов никак на красавицу спокойно говорить с своим неизменным , грустно и ехал на гору . « Вот не думал , — сказал князь Багратион , заметив Бориса не , в то же самое минуту . Перед князем княжна чувствовала на Пьера лицо Ростова , на которой столько часто думали о себе великого : — За что ? Хорошо ! Он , полковник , что вы мне не подите говорить про дело , il me месту ( — Я вас просить , Денисов ли ты хочешь , найдешь пользу . Борис с победой , дорог вы
# Epoch: 112/200 Iteration: 31000 Loss: 1.5097137689590454
# Зачем мне накануне . « Теперь я его дама у батюшка я . Вот так распоряжения ! Очень близко , mon père . ] — Et Lise ! » Так чтоб не слушая дам ему и тонко на лбу , дотронулся собой и в Лысых лицах его и стал ходить мимо него в ночь и каждый более солдат с ним из самых сладостных были . V Вечером мост и ему последние дела между слов как на нем прежде не потеряться о положении всё такой же не старались , и дальше , третье должно речь : de moi qui ne me me demandait de
# Epoch: 116/200 Iteration: 32000 Loss: 1.3885035514831543
# Зачем мне Кроме Je comprends encore » ) и , что она будет ходить под ним ; и он сказал к Пьеру ее , как в этом стояли и бросил свое положение быть известны усилием багрового : там на французского его , по которой столько , в этот этой еще весело и в нем скажи книзу тугой . Ростов зажмурился во княжну Марью как утром будто осторожно и радовался с Вдруг худым , смелым , как ни приезд того даже и себя втянутою как у них в высших духа и , сбоку запустив показался этот Анатоль сидел далеко , дотронувшись до нее блестящих
# Epoch: 119/200 Iteration: 33000 Loss: 1.250866174697876
# Зачем мне Смотрите австрийскому генералу от этих Николая . Они перешли или Анатоль не так на другой раз , а на чем и что Наполеон прежде в двери через канаву и лег , в густом дело было имение , чтобы обмануть их прошли говорить так и ясно . Как бы не может он целует несколько раз лице и опасные сидели у окна : император эти слова Наполеона . Она ответила в этот человека шел ) . Княгиня встрепенулась об общеизвестном об его одного , чем уже не перебил всех . « Зачем — C'est pas , [ Ты знаешь бы легко . Княжна
# Epoch: 123/200 Iteration: 34000 Loss: 1.4348289966583252
# Зачем мне Старшая о движениями внизу князя Андрея и считала : солдаты , раненые никак и последние старого , — ехал руки в Вене еще менее взгляда , как он был убит ; и сам всего , которые он ехал в Петербурге ; только могли бы принести большую ее и не выпустил в доме огромные mot одной , которая бывает на землю перебивая письмо сыну , налево с бутылкой началось для еще груди , та же же улыбка кресло » сердито . XVI они ее лицо и позу своей головой свои копошившихся . опустил глаза в зале . Не был для чего мост
# Epoch: 127/200 Iteration: 35000 Loss: 1.3172193765640259
# Зачем мне Кроме Да , что он так много счастия в ней какое-нибудь полк и спасти слово в том расположении духа , против Элен и поскакал назад в кабинет к , он и на военном поприще и сидела перед зеркалом сказал вместе и не видал дня к тому как такие , и не могла понять письмо , и в первый назад торопить одинаково солдата с лошадей . На душе его было из гусар Ростова . « Пускай ищет Но mon ami побежал на краю que plus méritoire и , [ Мой друг . Я не знаю , что это очень вам . Ни
# Epoch: 130/200 Iteration: 36000 Loss: 1.5494627952575684
# Зачем мне Может чувствует чаще и сели можно посмотрели всех на Элен . Как в самом деле было , но что , таких началось дело и так темно ; то ни ним за него люди , умирая , услыхал близкую знал , что сержант его лицо . Он видел его с видом желания избавиться ее для службы , что они отчаивались для них картечью с видом обратился и с ужасом на всю чувствовал себя . Разговор звуки государя Болконского есть решится нельзя понять было бы то ни было был бы ни сделать , подруги к Анне часть гостей , но не мог удержаться
# Epoch: 134/200 Iteration: 37000 Loss: 1.3070225715637207
# Зачем мне Может минутном мундира и атаковали карту поклонился , потому она , неестественно остатки ужина и в этих гостиных за столом ) и на хорах не любовь об дверь и по диспозиции показалось по первой письма тихо как вести любезно Бориса в руке ефес отца за ней в минуту в цепи ; но потом всё еще двух на штабных и всего , кто тут . В это чтобы сказать , но австрийский мы были на той же ленивой . В ней было он поджидал отставшие , не дожидаясь пять , как шли на минуту не верили в пять минут бы минуты :
# Epoch: 138/200 Iteration: 38000 Loss: 1.570134162902832
# Зачем мне Впрочем упала на ее живот : это очень скоро людей в том главнокомандующего ; Кутузов решился же необычайно . — Изволите партия тоже все получить , — прибавил денщик на дочь ? — сказал князь Долгоруков ! … Я обязан много последний , тогда мы да полка , помните , а к этим мне… — Нет еще ? — Не правда , — раздавался и , нахмуриваясь и естественностью что . Но в то что подлость… ; но вы , разумеется еще хуже им к непреодолимо : — Allez m'avez быстро » очень сконфуженный таких людей и вышел за главнокомандующим ,
# Epoch: 141/200 Iteration: 39000 Loss: 1.720225214958191
# Зачем мне Смотрите входить в десяти вместе , услыхав ; но с повязанною дня ? На всех , жил везде так много выпил . Как я к m-lle Денисова с любит ! Ежели горел оно княжна государю , право будет здесь . — Хорошо ! Только ты имел не основанная . Она не видя , большие казалось слез и не совсем , — сказала она робко свою поразило , — сказала она графу , которую мы всегда не будет всю свою месте с учтивым , в середине ее смотрели . Это дерево в Сибирь и даже по этому , как будто в своей
# Epoch: 145/200 Iteration: 40000 Loss: 1.511419653892517
# Зачем мне Может начинал писать с Высвободив 7 moi . — Ишь ты ! Боже мой для меня большим , — сказал фейерверкер жене замечал в том , как главное Тушин хотела точно только потому здесь на меня одного себя на свете ; то мы на войне , где она поэтому , что чрез же , как только как он переносит князя Андрея , как он был Наполеон на Ростова с тем вместе с князем Багратионом в армии ; то на то одна время показался дня стоял с тем нынче после их и огорчения . — Да что будет здесь ? — сказал
# Epoch: 149/200 Iteration: 41000 Loss: 1.341055154800415
# Зачем мне Кроме того времени слова темная хуже обращался он своих нисколько вмешалась , она так любила , что его не мог удержать всех ему , как будто спрашивая князь , и не раненые ; а потом князь , улыбаясь , но по смерти графа Безухова . Анна Михайловна дотронулась если колонны эти не отставать от письмо и за дорогих мнения о эту ночь с сыном ( так , что он не знал это в комнату , солнце ) . Несмотря , а еще худое которое ладонями его , не думал о это своем жизни . Жизнь было то , о чем он
# Epoch: 152/200 Iteration: 42000 Loss: 1.3855502605438232
# Зачем мне Смотрите Вели подумать ; положен на него ; коли он был адвокат всех была бы с двумя итальянскими , проговорила вдруг разные стороны , вошла в комнату стояли у Курагина ; он не знал , но не считал нужным исправляться в ней . Старый и с вашей столицей . Может быть есть дипломатические ее — в беспрерывных лошади могли двинуться вперед . « Боже мой ? Мы мое моя . Я пойду и подавая — вам . Посмотришь в вас нет ? — сказал Жерков , высокий и еще не мог понять революцию начальника человека , подойдя на самый капитан на
# Epoch: 156/200 Iteration: 43000 Loss: 1.3885414600372314
# Зачем мне Впрочем полковому торжественно всегда ; Телянин , bien так вперед и в этой комнате с высот . Все лица главнокомандующий ! — Нет ! Он , полковник Павлоградского гусарского быть tout ! Я не забуду , что , коли я вам говорил не так ? Ну мне , — сказала она с особенною уверенностию , [ Это ты не хочет , в то дела ! ] Только какой ли я не тужу . А был говорить это быть лучше за на казака и говорить так же страшно ? ] как пятьдесят поспешно ни приходится , капитан , в числе Анна Шерер
# Epoch: 159/200 Iteration: 44000 Loss: 1.2351055145263672
# Зачем мне Смотрите бедная говорится от костров были на мужа и повторяемыми ; из соседней левого фланга ; и глазами через цепь с лошади с твердым в те более и раздались звуки . Счастливое внизу уже недалеко . Он поскакал и всё удается и поэтому только говорили ( и по этому самому женщины и рассказывать в то же , что ей было ему ничего был убит было , что он попал нечаянно мимо . Но он уже чувствовал Бориса , как выражение усталости , князь Долгоруков перестал того только что , но она не сознавала было приятно . Но в противном случае главнокомандующий
# Epoch: 163/200 Iteration: 45000 Loss: 1.37570059299469
# Зачем мне Или чему он своих гостей и не умела и теперь того . Он пристально еще более обыкновенного . вопроса , прося их опровергнуты себе с таким значительным верхом , ласково чрез очки глядя на Анну Михайловну ; в четыре сына стоял в отчаянии . Сон усталости и остановился подле двух славных ближе был , желая из перекривленного руки во власти ; но с ним и оглянул обратилась к дамам с с голосом военного было же , — прибавил ему — Он улыбнулся и взялся . Пьер улыбался , не замок в сенях , и всё-таки в то , что уже в
# Epoch: 167/200 Iteration: 46000 Loss: 1.2900534868240356
# Зачем мне итти в мире и с наслаждением и над которым не может так времени ни это , а из праздник у него была ранена , на горе ? , почтительно наклонил им более в этой гостиной и совершенно новые получал с него глазами не слушал его ; но этот проходил быть вместе и многих и с тонкой лучше послал . Они сидели , не должен быть повторил адъютант . Багратион остановился рассматривать хорошенько французов в руках своего друга и с холодною . Так писала молчать , или , что ли он чего-нибудь назад с молодым , французы Кутузов , сопутствуемый двумя Болконских
# Epoch: 170/200 Iteration: 47000 Loss: 1.3378713130950928
# Зачем мне перейти любимый все дальнейшие мундирах » … — Он говорил ему , что вы думаете тот отца с тем выражением , что атака только для этого положения , что приезд не могла никто теперь : части другой день приехал к Буонапарте , что граф умер так и даже так любила еще , что интерес в кругу приглядевшихся лиц . — Ежели вам стоит говорила графиня , что это не так можете быть должны » . — Я это понимаю его : но это знаешь было . И действительно , право , знаешь ли , здравствуй , обедать на тебе удовольствия и
# Epoch: 174/200 Iteration: 48000 Loss: 1.2934919595718384
# Зачем мне некоторые судьбы спокойно всю состоянии сравнительно уже взглянул и не предполагали себя в состоянии шел медленно точно с своей стороны своего превосходства ; на его имя , она , так , и слезы навертывались ей эти слова свои мысли , когда она в дверь , и Тихон знал и в его полку , что это так , как он говорил с его голове от начальника , начала говорили , как полковой командир вздрагивал не счастливый звали Титом или его много то , что , на которой было уже подробно в штабе ему лучше , что потом знала не заслышались была хорошо
# Epoch: 178/200 Iteration: 49000 Loss: 1.4295977354049683
# Зачем мне ; кто бежавших к узнать и цареубийство , Анна была одна в ожидании руку руке лицом и этою дверью , рассуждать как и что-то говорил ему : все в деле , казалось , как и Анна Михайловна скрылась , а от него и князь Андрей , стараясь его на великого . Действительно , легко покажется ; далеко и толстый , утром с его лица ) ? Кто сказал Борис , в то же мгновение генералу их , а справедливость было была убеждена в эту это было было взял , когда он слышал свою проехали не был знамя . — Ну что
# Epoch: 181/200 Iteration: 50000 Loss: 1.6904550790786743
# Зачем мне получили . Этого никто ей велел . Он облокотился по знакомства . — Целуй : ты , я не знаю… ну тут ! Из маленького Анна вашего ! И фейерверкер пришел до роли и , покорно подчинялась должен хуже Долгоруков . Ежели бы вы , что я знаю то ? — говорил Долохов . В Москве кто-то , чувствуя еще невозможно . Пьер встал , исподлобья глядя посмотрел . Разговор начальства и неприятелю , подставив их . — Ребята ; придвинув одна Пьер не сказал был : « Chère , — сказал Пьер с собой так долго к англичанину . Увидав
# Epoch: 185/200 Iteration: 51000 Loss: 1.290414571762085
# Зачем мне некоторые знакомые ! И потом выступили то на ней не знал только в том дело , а , пока этого , что ты сделал мост судим в его сердце ? Князь всё еще не звал . Вы , всё будет его и за то же . И он и мой муж еще более с его орудиями » ? А так нужно , но стеснительна в глазах других так , кто их не смотрел на это ? Потом в кибиточке , он был только оттого , что нужно ему в одно впечатление . Пьер с кресла лицом поехал с дочь этой другом
# Epoch: 189/200 Iteration: 52000 Loss: 1.3444218635559082
# Зачем мне перейти приехал . Я того отец и здесь не будет , ma bonne compagnie un mot [ Но за Долохова в меня нет ! Что я еще верила на такая человека , нет , пожалуйста… это премия ] с думала на диван ) о любви ? Это была , что они отчаивались . Но я не желаю быть , чем другой про вас . Он протянул все хорошо , как вы всем брат , однако , ваше сиятельство ? И князь ? — спросила княгиня . Он женщины , который звал на этого времени не слышал и Пьеру : Бог )
# Epoch: 192/200 Iteration: 53000 Loss: 1.3972920179367065
# Зачем мне мысленно графине к генералу , несла наших получит гостиной . Князь остановился . — Нарядные говорят за локоть ; но в то и показала путем , коли вы мне ? Теперь что его величеству . Эрцгерцогиня тоже , как и Анна , не может так права . Действительно солдаты не так страшен не уши своей хотелось еще , как при этом никого было ужасно , и сложить Анатоль с страшным , услыхав шаги . — Генерал-аншеф — крикнул князь . ] Кроме того вы князь Андрей ? Теперь ты решился не знаете ; он с беременною женой , видимо ! —
# Epoch: 196/200 Iteration: 54000 Loss: 1.3461288213729858
# Зачем мне ? Они выехали ? У тебя в фельдмаршалы ? — Я завтра , я желал бы не только , как вам уж до такой скажу , что вы бы ни слова ! Ну , батюшка ! .. при которых я пойду и спрошу графа , — как он меня любит его ? Не только то мне знать его от мной в зеркало в лицо к . « II est Урра ! à la dépêche de cet vous . Неужели ты точно mon ami , que mon comme les suivre кто скорее ! ] В подает лицах войск ces поцеловал . Он
# Epoch: 199/200 Iteration: 55000 Loss: 1.2760920524597168
# Зачем мне ? На меня внимание сидели во всё время чтения о смерти его лошади : я знаю только в случае графа . Это случае графа , на это , он сам пишет о ее был сказать то туда князь и сухо , то , как мне наконец на своих гусар уже присоединился слишком огромного для того . Опуская двери уже два , что , но он был очень не могло бы этот другой не может . Как он мне умереть в мыслях княжны , и обратилась , и я не любила вам помню человеку , что он всё узнаем ее жизни .

# %%
net.cpu()
save = {"net":net.state_dict(), \
        "n_vocab":n_vocab, \
        "vocab_to_int":vocab_to_int,\
        "int_to_vocab":int_to_vocab}
torch.save(save, "net.dict")

# %% [markdown]
# ### Пробуем делать предсказания

# %% [markdown]
# Функция predict принимает на вход следующие аргументы:
# * device: на каком устройстве выполняются предсказания - см. предыдущую ячейку
# * net: обученная нейросеть - см. предыдущую ячейку
# * n_vocab: число слов в словаре - см. раздел Подготовка данных
# * vocab_to_int: словарь, возвращающий номер слова - см. раздел Подготовка данных
# * int_to_vocab: словарь, возвращающий слова по их номеру - см. раздел Подготовка данных
# * (!) my_input: строка, которую нужно продолжить
# * (!) top_k: из скольки слов с наибольшими предсказанными вероятностями выбирать следующее слово
# * (!) length: сколько слов генерировать

# %%
my_input = "Я"
predict(device, net, n_vocab, vocab_to_int, int_to_vocab, \
        my_input, top_k=1, length=20)
# Out:
# Я вас люблю , — сказал он , — я повторить не могу , — невозможно . — Это-то мы и посмотрим

# %%
my_input = "Завтра поедем выбирать новую шубу"
predict(device, net, n_vocab,
                    vocab_to_int, int_to_vocab, my_input, top_k=1,\
       length=10)
# Out:
# Завтра поедем выбирать новую шубу , — сказала старая графиня , проходя через залу и улыбнулась

# %%
my_input = "Завтра поедем выбирать новую машину"
predict(device, net, n_vocab,
                    vocab_to_int, int_to_vocab, my_input, top_k=1,\
       length=10)
# Out:
# Завтра поедем выбирать новую машину . Но князь Василий ? — спросила графиня . — Ах

# %%
my_input = "Завтра поедем выбирать новое платье"
predict(device, net, n_vocab,
                    vocab_to_int, int_to_vocab, my_input, top_k=1,\
       length=10)
# Out:
# Завтра поедем выбирать новое платье . Ее находят прекрасною , как бы счастливая их . —

# %%
my_input = "Василий  Денисов ,  друг"
result = predict(device, net, n_vocab,
                    vocab_to_int, int_to_vocab, my_input, top_k=1,\
       length=20)
result
# Out:
# Василий Денисов , друг сердечный , как вы ко всем министрам , ко всему . Если Богу угодно будет испытать тебя . Вот так бедны
# 'Василий Денисов , друг сердечный , как вы ко всем министрам , ко всему . Если Богу угодно будет испытать тебя . Вот так бедны'

# %% [markdown]
# Попробуйте генерировать слои предсказания в ноутбуке с заданием!
